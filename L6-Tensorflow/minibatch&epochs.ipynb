# %%
import math
import tensorflow as tf
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data

# %% [markdown]
# # Mini-batch

# %%
# 4 Samples of features
example_features = [
    ['F11','F12','F13','F14'],
    ['F21','F22','F23','F24'],
    ['F31','F32','F33','F34'],
    ['F41','F42','F43','F44']]
# 4 Samples of labels
example_labels = [
    ['L11','L12'],
    ['L21','L22'],
    ['L31','L32'],
    ['L41','L42']]

# %%
def batches(batch_size, features, labels):
    assert len(features) == len(labels)
    mini_batches = []
    sample_size = len(features)
    for i in range(0, sample_size, batch_size):
        batch = [features[i:i + batch_size], labels[i:i + batch_size]]
        mini_batches.append(batch)
    return mini_batches
    
print(batches(3, example_features, example_labels))
# Out:
# [[[['F11', 'F12', 'F13', 'F14'], ['F21', 'F22', 'F23', 'F24'], ['F31', 'F32', 'F33', 'F34']], [['L11', 'L12'], ['L21', 'L22'], ['L31', 'L32']]], [[['F41', 'F42', 'F43', 'F44']], [['L41', 'L42']]]]

# %% [markdown]
# # epochs
# validation set

# %%
def print_epoch_stats(epoch_i, sess, last_features, last_labels):
    """
    Print cost and validation accuracy of an epoch
    """
    current_cost = sess.run(
        cost,
        feed_dict={features: last_features, labels: last_labels})
    valid_accuracy = sess.run(
        accuracy,
        feed_dict={features: valid_features, labels: valid_labels})
    print('Epoch: {:<4} - Cost: {:<8.3} Valid Accuracy: {:<5.3}'.format(
        epoch_i,
        current_cost,
        valid_accuracy))

# %% [markdown]
# # MNIST test

# %%
n_input = 784  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)

# Import MNIST data
mnist = input_data.read_data_sets('./mnist', one_hot=True)

# The features are already scaled and the data is shuffled
train_features = mnist.train.images
valid_features = mnist.validation.images
test_features = mnist.test.images

train_labels = mnist.train.labels.astype(np.float32)
valid_labels = mnist.validation.labels.astype(np.float32)
test_labels = mnist.test.labels.astype(np.float32)

# Features and Labels
features = tf.placeholder(tf.float32, [None, n_input])
labels = tf.placeholder(tf.float32, [None, n_classes])

# Weights & bias
weights = tf.Variable(tf.random_normal([n_input, n_classes]))
bias = tf.Variable(tf.random_normal([n_classes]))

# Logits - xW + b
logits = tf.add(tf.matmul(features, weights), bias)

# Define learning_rate, loss and optimizer
learning_rate = tf.placeholder(tf.float32)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost)

# Calculate accuracy
correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))


# hyper parameters
batch_size = 128
epochs = 200
learn_rate = 0.002

init = tf.global_variables_initializer()
# Out:
# Extracting ./mnist/train-images-idx3-ubyte.gz
# Extracting ./mnist/train-labels-idx1-ubyte.gz
# Extracting ./mnist/t10k-images-idx3-ubyte.gz
# Extracting ./mnist/t10k-labels-idx1-ubyte.gz

# %%
mini_batches = batches(batch_size, train_features, train_labels)

# %%
# %%time
# wall time is the real time
with tf.Session() as sess:
    sess.run(init)
    
    for epoch_i in range(epochs):
        # for loop two variable, the details?
        for batch_features, batch_labels in mini_batches:
            train_feed_dict = {
                features: batch_features,
                labels: batch_labels,
                learning_rate: learn_rate}
            sess.run(optimizer, feed_dict=train_feed_dict)
#         print(learn_rate)
        print_epoch_stats(epoch_i, sess, batch_features, batch_labels)

    # Calculate accuracy for test dataset
    test_accuracy = sess.run(accuracy, feed_dict={features: test_features, labels: test_labels})

print('Test Accuracy: {}'.format(test_accuracy))
# Out:
# Epoch: 0    - Cost: 12.8     Valid Accuracy: 0.1
# Epoch: 1    - Cost: 11.0     Valid Accuracy: 0.142
# Epoch: 2    - Cost: 9.99     Valid Accuracy: 0.187
# Epoch: 3    - Cost: 9.22     Valid Accuracy: 0.226
# Epoch: 4    - Cost: 8.57     Valid Accuracy: 0.256
# Epoch: 5    - Cost: 8.01     Valid Accuracy: 0.28
# Epoch: 6    - Cost: 7.5      Valid Accuracy: 0.305
# Epoch: 7    - Cost: 7.04     Valid Accuracy: 0.332
# Epoch: 8    - Cost: 6.62     Valid Accuracy: 0.361
# Epoch: 9    - Cost: 6.24     Valid Accuracy: 0.384
# Epoch: 10   - Cost: 5.89     Valid Accuracy: 0.405
# Epoch: 11   - Cost: 5.58     Valid Accuracy: 0.43
# Epoch: 12   - Cost: 5.3      Valid Accuracy: 0.449
# Epoch: 13   - Cost: 5.05     Valid Accuracy: 0.469
# Epoch: 14   - Cost: 4.83     Valid Accuracy: 0.492
# Epoch: 15   - Cost: 4.63     Valid Accuracy: 0.508
# Epoch: 16   - Cost: 4.46     Valid Accuracy: 0.524
# Epoch: 17   - Cost: 4.3      Valid Accuracy: 0.54
# Epoch: 18   - Cost: 4.16     Valid Accuracy: 0.554
# Epoch: 19   - Cost: 4.03     Valid Accuracy: 0.567
# Epoch: 20   - Cost: 3.92     Valid Accuracy: 0.58
# Epoch: 21   - Cost: 3.81     Valid Accuracy: 0.589
# Epoch: 22   - Cost: 3.72     Valid Accuracy: 0.6
# Epoch: 23   - Cost: 3.63     Valid Accuracy: 0.61
# Epoch: 24   - Cost: 3.55     Valid Accuracy: 0.616
# Epoch: 25   - Cost: 3.47     Valid Accuracy: 0.623
# Epoch: 26   - Cost: 3.4      Valid Accuracy: 0.63
# Epoch: 27   - Cost: 3.33     Valid Accuracy: 0.636
# Epoch: 28   - Cost: 3.27     Valid Accuracy: 0.644
# Epoch: 29   - Cost: 3.2      Valid Accuracy: 0.65
# Epoch: 30   - Cost: 3.15     Valid Accuracy: 0.657
# Epoch: 31   - Cost: 3.09     Valid Accuracy: 0.659
# Epoch: 32   - Cost: 3.04     Valid Accuracy: 0.663
# Epoch: 33   - Cost: 2.99     Valid Accuracy: 0.669
# Epoch: 34   - Cost: 2.94     Valid Accuracy: 0.674
# Epoch: 35   - Cost: 2.9      Valid Accuracy: 0.679
# Epoch: 36   - Cost: 2.85     Valid Accuracy: 0.683
# Epoch: 37   - Cost: 2.81     Valid Accuracy: 0.687
# Epoch: 38   - Cost: 2.77     Valid Accuracy: 0.691
# Epoch: 39   - Cost: 2.73     Valid Accuracy: 0.694
# Epoch: 40   - Cost: 2.7      Valid Accuracy: 0.698
# Epoch: 41   - Cost: 2.66     Valid Accuracy: 0.702
# Epoch: 42   - Cost: 2.63     Valid Accuracy: 0.705
# Epoch: 43   - Cost: 2.59     Valid Accuracy: 0.71
# Epoch: 44   - Cost: 2.56     Valid Accuracy: 0.712
# Epoch: 45   - Cost: 2.53     Valid Accuracy: 0.714
# Epoch: 46   - Cost: 2.5      Valid Accuracy: 0.718
# Epoch: 47   - Cost: 2.47     Valid Accuracy: 0.721
# Epoch: 48   - Cost: 2.44     Valid Accuracy: 0.724
# Epoch: 49   - Cost: 2.41     Valid Accuracy: 0.727
# Epoch: 50   - Cost: 2.39     Valid Accuracy: 0.729
# Epoch: 51   - Cost: 2.36     Valid Accuracy: 0.732
# Epoch: 52   - Cost: 2.34     Valid Accuracy: 0.734
# Epoch: 53   - Cost: 2.31     Valid Accuracy: 0.737
# Epoch: 54   - Cost: 2.29     Valid Accuracy: 0.739
# Epoch: 55   - Cost: 2.26     Valid Accuracy: 0.741
# Epoch: 56   - Cost: 2.24     Valid Accuracy: 0.743
# Epoch: 57   - Cost: 2.22     Valid Accuracy: 0.746
# Epoch: 58   - Cost: 2.2      Valid Accuracy: 0.748
# Epoch: 59   - Cost: 2.18     Valid Accuracy: 0.749
# Epoch: 60   - Cost: 2.16     Valid Accuracy: 0.75
# Epoch: 61   - Cost: 2.14     Valid Accuracy: 0.751
# Epoch: 62   - Cost: 2.12     Valid Accuracy: 0.753
# Epoch: 63   - Cost: 2.1      Valid Accuracy: 0.754
# Epoch: 64   - Cost: 2.08     Valid Accuracy: 0.755
# Epoch: 65   - Cost: 2.06     Valid Accuracy: 0.757
# Epoch: 66   - Cost: 2.04     Valid Accuracy: 0.758
# Epoch: 67   - Cost: 2.03     Valid Accuracy: 0.76
# Epoch: 68   - Cost: 2.01     Valid Accuracy: 0.762
# Epoch: 69   - Cost: 1.99     Valid Accuracy: 0.763
# Epoch: 70   - Cost: 1.98     Valid Accuracy: 0.765
# Epoch: 71   - Cost: 1.96     Valid Accuracy: 0.766
# Epoch: 72   - Cost: 1.95     Valid Accuracy: 0.766
# Epoch: 73   - Cost: 1.93     Valid Accuracy: 0.769
# Epoch: 74   - Cost: 1.92     Valid Accuracy: 0.77
# Epoch: 75   - Cost: 1.9      Valid Accuracy: 0.772
# Epoch: 76   - Cost: 1.89     Valid Accuracy: 0.775
# Epoch: 77   - Cost: 1.88     Valid Accuracy: 0.776
# Epoch: 78   - Cost: 1.86     Valid Accuracy: 0.777
# Epoch: 79   - Cost: 1.85     Valid Accuracy: 0.777
# Epoch: 80   - Cost: 1.84     Valid Accuracy: 0.778
# Epoch: 81   - Cost: 1.82     Valid Accuracy: 0.78
# Epoch: 82   - Cost: 1.81     Valid Accuracy: 0.781
# Epoch: 83   - Cost: 1.8      Valid Accuracy: 0.782
# Epoch: 84   - Cost: 1.79     Valid Accuracy: 0.783
# Epoch: 85   - Cost: 1.78     Valid Accuracy: 0.786
# Epoch: 86   - Cost: 1.77     Valid Accuracy: 0.787
# Epoch: 87   - Cost: 1.75     Valid Accuracy: 0.788
# Epoch: 88   - Cost: 1.74     Valid Accuracy: 0.788
# Epoch: 89   - Cost: 1.73     Valid Accuracy: 0.789
# Epoch: 90   - Cost: 1.72     Valid Accuracy: 0.791
# Epoch: 91   - Cost: 1.71     Valid Accuracy: 0.792
# Epoch: 92   - Cost: 1.7      Valid Accuracy: 0.793
# Epoch: 93   - Cost: 1.69     Valid Accuracy: 0.793
# Epoch: 94   - Cost: 1.68     Valid Accuracy: 0.794
# Epoch: 95   - Cost: 1.67     Valid Accuracy: 0.794
# Epoch: 96   - Cost: 1.66     Valid Accuracy: 0.795
# Epoch: 97   - Cost: 1.65     Valid Accuracy: 0.795
# Epoch: 98   - Cost: 1.65     Valid Accuracy: 0.796
# Epoch: 99   - Cost: 1.64     Valid Accuracy: 0.797
# Epoch: 100  - Cost: 1.63     Valid Accuracy: 0.798
# Epoch: 101  - Cost: 1.62     Valid Accuracy: 0.799
# Epoch: 102  - Cost: 1.61     Valid Accuracy: 0.799
# Epoch: 103  - Cost: 1.6      Valid Accuracy: 0.799
# Epoch: 104  - Cost: 1.59     Valid Accuracy: 0.8
# Epoch: 105  - Cost: 1.59     Valid Accuracy: 0.8
# Epoch: 106  - Cost: 1.58     Valid Accuracy: 0.802
# Epoch: 107  - Cost: 1.57     Valid Accuracy: 0.803
# Epoch: 108  - Cost: 1.56     Valid Accuracy: 0.804
# Epoch: 109  - Cost: 1.55     Valid Accuracy: 0.804
# Epoch: 110  - Cost: 1.55     Valid Accuracy: 0.805
# Epoch: 111  - Cost: 1.54     Valid Accuracy: 0.805
# Epoch: 112  - Cost: 1.53     Valid Accuracy: 0.805
# Epoch: 113  - Cost: 1.52     Valid Accuracy: 0.805
# Epoch: 114  - Cost: 1.52     Valid Accuracy: 0.806
# Epoch: 115  - Cost: 1.51     Valid Accuracy: 0.807
# Epoch: 116  - Cost: 1.5      Valid Accuracy: 0.808
# Epoch: 117  - Cost: 1.5      Valid Accuracy: 0.808
# Epoch: 118  - Cost: 1.49     Valid Accuracy: 0.81
# Epoch: 119  - Cost: 1.48     Valid Accuracy: 0.81
# Epoch: 120  - Cost: 1.48     Valid Accuracy: 0.811
# Epoch: 121  - Cost: 1.47     Valid Accuracy: 0.812
# Epoch: 122  - Cost: 1.46     Valid Accuracy: 0.812
# Epoch: 123  - Cost: 1.46     Valid Accuracy: 0.813
# Epoch: 124  - Cost: 1.45     Valid Accuracy: 0.814
# Epoch: 125  - Cost: 1.44     Valid Accuracy: 0.813
# Epoch: 126  - Cost: 1.44     Valid Accuracy: 0.814
# Epoch: 127  - Cost: 1.43     Valid Accuracy: 0.815
# Epoch: 128  - Cost: 1.43     Valid Accuracy: 0.815
# Epoch: 129  - Cost: 1.42     Valid Accuracy: 0.816
# Epoch: 130  - Cost: 1.41     Valid Accuracy: 0.817
# Epoch: 131  - Cost: 1.41     Valid Accuracy: 0.818
# Epoch: 132  - Cost: 1.4      Valid Accuracy: 0.819
# Epoch: 133  - Cost: 1.4      Valid Accuracy: 0.82
# Epoch: 134  - Cost: 1.39     Valid Accuracy: 0.821
# Epoch: 135  - Cost: 1.39     Valid Accuracy: 0.821
# Epoch: 136  - Cost: 1.38     Valid Accuracy: 0.821
# Epoch: 137  - Cost: 1.38     Valid Accuracy: 0.822
# Epoch: 138  - Cost: 1.37     Valid Accuracy: 0.822
# Epoch: 139  - Cost: 1.36     Valid Accuracy: 0.822
# Epoch: 140  - Cost: 1.36     Valid Accuracy: 0.822
# Epoch: 141  - Cost: 1.35     Valid Accuracy: 0.823
# Epoch: 142  - Cost: 1.35     Valid Accuracy: 0.823
# Epoch: 143  - Cost: 1.34     Valid Accuracy: 0.824
# Epoch: 144  - Cost: 1.34     Valid Accuracy: 0.824
# Epoch: 145  - Cost: 1.33     Valid Accuracy: 0.824
# Epoch: 146  - Cost: 1.33     Valid Accuracy: 0.825
# Epoch: 147  - Cost: 1.32     Valid Accuracy: 0.826
# Epoch: 148  - Cost: 1.32     Valid Accuracy: 0.825
# Epoch: 149  - Cost: 1.31     Valid Accuracy: 0.826
# Epoch: 150  - Cost: 1.31     Valid Accuracy: 0.826
# Epoch: 151  - Cost: 1.3      Valid Accuracy: 0.826
# Epoch: 152  - Cost: 1.3      Valid Accuracy: 0.827
# Epoch: 153  - Cost: 1.3      Valid Accuracy: 0.827
# Epoch: 154  - Cost: 1.29     Valid Accuracy: 0.827
# Epoch: 155  - Cost: 1.29     Valid Accuracy: 0.828
# Epoch: 156  - Cost: 1.28     Valid Accuracy: 0.828
# Epoch: 157  - Cost: 1.28     Valid Accuracy: 0.829
# Epoch: 158  - Cost: 1.27     Valid Accuracy: 0.829
# Epoch: 159  - Cost: 1.27     Valid Accuracy: 0.829
# Epoch: 160  - Cost: 1.26     Valid Accuracy: 0.83
# Epoch: 161  - Cost: 1.26     Valid Accuracy: 0.83
# Epoch: 162  - Cost: 1.26     Valid Accuracy: 0.83
# Epoch: 163  - Cost: 1.25     Valid Accuracy: 0.83
# Epoch: 164  - Cost: 1.25     Valid Accuracy: 0.831
# Epoch: 165  - Cost: 1.24     Valid Accuracy: 0.831
# Epoch: 166  - Cost: 1.24     Valid Accuracy: 0.831
# Epoch: 167  - Cost: 1.23     Valid Accuracy: 0.832
# Epoch: 168  - Cost: 1.23     Valid Accuracy: 0.832
# Epoch: 169  - Cost: 1.23     Valid Accuracy: 0.832
# Epoch: 170  - Cost: 1.22     Valid Accuracy: 0.833
# Epoch: 171  - Cost: 1.22     Valid Accuracy: 0.833
# Epoch: 172  - Cost: 1.22     Valid Accuracy: 0.833
# Epoch: 173  - Cost: 1.21     Valid Accuracy: 0.833
# Epoch: 174  - Cost: 1.21     Valid Accuracy: 0.833
# Epoch: 175  - Cost: 1.2      Valid Accuracy: 0.833
# Epoch: 176  - Cost: 1.2      Valid Accuracy: 0.834
# Epoch: 177  - Cost: 1.2      Valid Accuracy: 0.834
# Epoch: 178  - Cost: 1.19     Valid Accuracy: 0.834
# Epoch: 179  - Cost: 1.19     Valid Accuracy: 0.835
# Epoch: 180  - Cost: 1.19     Valid Accuracy: 0.835
# Epoch: 181  - Cost: 1.18     Valid Accuracy: 0.836
# Epoch: 182  - Cost: 1.18     Valid Accuracy: 0.836
# Epoch: 183  - Cost: 1.17     Valid Accuracy: 0.836
# Epoch: 184  - Cost: 1.17     Valid Accuracy: 0.836
# Epoch: 185  - Cost: 1.17     Valid Accuracy: 0.836
# Epoch: 186  - Cost: 1.16     Valid Accuracy: 0.837
# Epoch: 187  - Cost: 1.16     Valid Accuracy: 0.837
# Epoch: 188  - Cost: 1.16     Valid Accuracy: 0.837
# Epoch: 189  - Cost: 1.15     Valid Accuracy: 0.837
# Epoch: 190  - Cost: 1.15     Valid Accuracy: 0.837
# Epoch: 191  - Cost: 1.15     Valid Accuracy: 0.837
# Epoch: 192  - Cost: 1.14     Valid Accuracy: 0.838
# Epoch: 193  - Cost: 1.14     Valid Accuracy: 0.838
# Epoch: 194  - Cost: 1.14     Valid Accuracy: 0.838
# Epoch: 195  - Cost: 1.13     Valid Accuracy: 0.839
# Epoch: 196  - Cost: 1.13     Valid Accuracy: 0.839
# Epoch: 197  - Cost: 1.13     Valid Accuracy: 0.839
# Epoch: 198  - Cost: 1.12     Valid Accuracy: 0.839
# Epoch: 199  - Cost: 1.12     Valid Accuracy: 0.84
# Test Accuracy: 0.842199981213
# CPU times: user 2min 28s, sys: 6.35 s, total: 2min 34s
# Wall time: 1min 26s
