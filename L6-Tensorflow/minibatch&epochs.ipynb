# %%
import math
import tensorflow as tf
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data

# %% [markdown]
# # Mini-batch

# %%
# 4 Samples of features
example_features = [
    ['F11','F12','F13','F14'],
    ['F21','F22','F23','F24'],
    ['F31','F32','F33','F34'],
    ['F41','F42','F43','F44']]
# 4 Samples of labels
example_labels = [
    ['L11','L12'],
    ['L21','L22'],
    ['L31','L32'],
    ['L41','L42']]

# %%
def batches(batch_size, features, labels):
    assert len(features) == len(labels)
    mini_batches = []
    sample_size = len(features)
    for i in range(0, sample_size, batch_size):
        batch = [features[i:i + batch_size], labels[i:i + batch_size]]
        mini_batches.append(batch)
    return mini_batches
    
print(batches(3, example_features, example_labels))
# Out:
# [[[['F11', 'F12', 'F13', 'F14'], ['F21', 'F22', 'F23', 'F24'], ['F31', 'F32', 'F33', 'F34']], [['L11', 'L12'], ['L21', 'L22'], ['L31', 'L32']]], [[['F41', 'F42', 'F43', 'F44']], [['L41', 'L42']]]]

# %% [markdown]
# # epochs
# validation set

# %%
def print_epoch_stats(epoch_i, sess, last_features, last_labels):
    """
    Print cost and validation accuracy of an epoch
    """
    current_cost = sess.run(
        cost,
        feed_dict={features: last_features, labels: last_labels})
    valid_accuracy = sess.run(
        accuracy,
        feed_dict={features: valid_features, labels: valid_labels})
    print('Epoch: {:<4} - Cost: {:<8.3} Valid Accuracy: {:<5.3}'.format(
        epoch_i,
        current_cost,
        valid_accuracy))

# %% [markdown]
# # MNIST test

# %%
n_input = 784  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)

# Import MNIST data
mnist = input_data.read_data_sets('./mnist', one_hot=True)

# The features are already scaled and the data is shuffled
train_features = mnist.train.images
valid_features = mnist.validation.images
test_features = mnist.test.images

train_labels = mnist.train.labels.astype(np.float32)
valid_labels = mnist.validation.labels.astype(np.float32)
test_labels = mnist.test.labels.astype(np.float32)

# Features and Labels
features = tf.placeholder(tf.float32, [None, n_input])
labels = tf.placeholder(tf.float32, [None, n_classes])

# Weights & bias
weights = tf.Variable(tf.random_normal([n_input, n_classes]))
bias = tf.Variable(tf.random_normal([n_classes]))

# Logits - xW + b
logits = tf.add(tf.matmul(features, weights), bias)

# Define learning_rate, loss and optimizer
learning_rate = tf.placeholder(tf.float32)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost)

# Calculate accuracy
correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))


# hyper parameters
batch_size = 128
epochs = 200
learn_rate = 0.001

init = tf.global_variables_initializer()
# Out:
# Extracting ./mnist/train-images-idx3-ubyte.gz
# Extracting ./mnist/train-labels-idx1-ubyte.gz
# Extracting ./mnist/t10k-images-idx3-ubyte.gz
# Extracting ./mnist/t10k-labels-idx1-ubyte.gz

# %%
mini_batches = batches(batch_size, train_features, train_labels)

# %%
# %%time
with tf.Session() as sess:
    sess.run(init)
    
    for epoch_i in range(epochs):
        # for loop two variable, the details?
        for batch_features, batch_labels in mini_batches:
            train_feed_dict = {
                features: batch_features,
                labels: batch_labels,
                learning_rate: learn_rate}
            sess.run(optimizer, feed_dict=train_feed_dict)
        print_epoch_stats(epoch_i, sess, batch_features, batch_labels)

    # Calculate accuracy for test dataset
    test_accuracy = sess.run(accuracy, feed_dict={features: test_features, labels: test_labels})

print('Test Accuracy: {}'.format(test_accuracy))
# Out:
# Epoch: 0    - Cost: 13.0     Valid Accuracy: 0.0602
# Epoch: 1    - Cost: 11.8     Valid Accuracy: 0.075
# Epoch: 2    - Cost: 10.9     Valid Accuracy: 0.0972
# Epoch: 3    - Cost: 10.1     Valid Accuracy: 0.119
# Epoch: 4    - Cost: 9.48     Valid Accuracy: 0.141
# Epoch: 5    - Cost: 8.95     Valid Accuracy: 0.158
# Epoch: 6    - Cost: 8.5      Valid Accuracy: 0.175
# Epoch: 7    - Cost: 8.11     Valid Accuracy: 0.193
# Epoch: 8    - Cost: 7.77     Valid Accuracy: 0.211
# Epoch: 9    - Cost: 7.46     Valid Accuracy: 0.231
# Epoch: 10   - Cost: 7.18     Valid Accuracy: 0.249
# Epoch: 11   - Cost: 6.92     Valid Accuracy: 0.27
# Epoch: 12   - Cost: 6.68     Valid Accuracy: 0.29
# Epoch: 13   - Cost: 6.46     Valid Accuracy: 0.305
# Epoch: 14   - Cost: 6.26     Valid Accuracy: 0.319
# Epoch: 15   - Cost: 6.06     Valid Accuracy: 0.332
# Epoch: 16   - Cost: 5.89     Valid Accuracy: 0.345
# Epoch: 17   - Cost: 5.72     Valid Accuracy: 0.36
# Epoch: 18   - Cost: 5.56     Valid Accuracy: 0.371
# Epoch: 19   - Cost: 5.41     Valid Accuracy: 0.382
# Epoch: 20   - Cost: 5.27     Valid Accuracy: 0.393
# Epoch: 21   - Cost: 5.14     Valid Accuracy: 0.407
# Epoch: 22   - Cost: 5.01     Valid Accuracy: 0.42
# Epoch: 23   - Cost: 4.9      Valid Accuracy: 0.432
# Epoch: 24   - Cost: 4.78     Valid Accuracy: 0.444
# Epoch: 25   - Cost: 4.68     Valid Accuracy: 0.454
# Epoch: 26   - Cost: 4.58     Valid Accuracy: 0.465
# Epoch: 27   - Cost: 4.48     Valid Accuracy: 0.473
# Epoch: 28   - Cost: 4.39     Valid Accuracy: 0.481
# Epoch: 29   - Cost: 4.3      Valid Accuracy: 0.491
# Epoch: 30   - Cost: 4.21     Valid Accuracy: 0.498
# Epoch: 31   - Cost: 4.13     Valid Accuracy: 0.506
# Epoch: 32   - Cost: 4.05     Valid Accuracy: 0.515
# Epoch: 33   - Cost: 3.98     Valid Accuracy: 0.523
# Epoch: 34   - Cost: 3.9      Valid Accuracy: 0.527
# Epoch: 35   - Cost: 3.83     Valid Accuracy: 0.533
# Epoch: 36   - Cost: 3.77     Valid Accuracy: 0.541
# Epoch: 37   - Cost: 3.7      Valid Accuracy: 0.549
# Epoch: 38   - Cost: 3.64     Valid Accuracy: 0.555
# Epoch: 39   - Cost: 3.58     Valid Accuracy: 0.56
# Epoch: 40   - Cost: 3.52     Valid Accuracy: 0.567
# Epoch: 41   - Cost: 3.47     Valid Accuracy: 0.57
# Epoch: 42   - Cost: 3.41     Valid Accuracy: 0.574
# Epoch: 43   - Cost: 3.36     Valid Accuracy: 0.58
# Epoch: 44   - Cost: 3.31     Valid Accuracy: 0.583
# Epoch: 45   - Cost: 3.27     Valid Accuracy: 0.586
# Epoch: 46   - Cost: 3.22     Valid Accuracy: 0.59
# Epoch: 47   - Cost: 3.17     Valid Accuracy: 0.593
# Epoch: 48   - Cost: 3.13     Valid Accuracy: 0.598
# Epoch: 49   - Cost: 3.09     Valid Accuracy: 0.602
# Epoch: 50   - Cost: 3.05     Valid Accuracy: 0.607
# Epoch: 51   - Cost: 3.01     Valid Accuracy: 0.609
# Epoch: 52   - Cost: 2.97     Valid Accuracy: 0.612
# Epoch: 53   - Cost: 2.94     Valid Accuracy: 0.615
# Epoch: 54   - Cost: 2.9      Valid Accuracy: 0.62
# Epoch: 55   - Cost: 2.87     Valid Accuracy: 0.623
# Epoch: 56   - Cost: 2.83     Valid Accuracy: 0.627
# Epoch: 57   - Cost: 2.8      Valid Accuracy: 0.63
# Epoch: 58   - Cost: 2.77     Valid Accuracy: 0.632
# Epoch: 59   - Cost: 2.74     Valid Accuracy: 0.634
# Epoch: 60   - Cost: 2.71     Valid Accuracy: 0.637
# Epoch: 61   - Cost: 2.68     Valid Accuracy: 0.64
# Epoch: 62   - Cost: 2.66     Valid Accuracy: 0.643
# Epoch: 63   - Cost: 2.63     Valid Accuracy: 0.645
# Epoch: 64   - Cost: 2.6      Valid Accuracy: 0.648
# Epoch: 65   - Cost: 2.58     Valid Accuracy: 0.65
# Epoch: 66   - Cost: 2.55     Valid Accuracy: 0.652
# Epoch: 67   - Cost: 2.53     Valid Accuracy: 0.655
# Epoch: 68   - Cost: 2.51     Valid Accuracy: 0.658
# Epoch: 69   - Cost: 2.48     Valid Accuracy: 0.661
# Epoch: 70   - Cost: 2.46     Valid Accuracy: 0.665
# Epoch: 71   - Cost: 2.44     Valid Accuracy: 0.668
# Epoch: 72   - Cost: 2.42     Valid Accuracy: 0.669
# Epoch: 73   - Cost: 2.4      Valid Accuracy: 0.672
# Epoch: 74   - Cost: 2.38     Valid Accuracy: 0.673
# Epoch: 75   - Cost: 2.36     Valid Accuracy: 0.676
# Epoch: 76   - Cost: 2.34     Valid Accuracy: 0.678
# Epoch: 77   - Cost: 2.33     Valid Accuracy: 0.681
# Epoch: 78   - Cost: 2.31     Valid Accuracy: 0.683
# Epoch: 79   - Cost: 2.29     Valid Accuracy: 0.686
# Epoch: 80   - Cost: 2.27     Valid Accuracy: 0.687
# Epoch: 81   - Cost: 2.26     Valid Accuracy: 0.689
# Epoch: 82   - Cost: 2.24     Valid Accuracy: 0.69
# Epoch: 83   - Cost: 2.22     Valid Accuracy: 0.691
# Epoch: 84   - Cost: 2.21     Valid Accuracy: 0.694
# Epoch: 85   - Cost: 2.19     Valid Accuracy: 0.696
# Epoch: 86   - Cost: 2.18     Valid Accuracy: 0.697
# Epoch: 87   - Cost: 2.16     Valid Accuracy: 0.7
# Epoch: 88   - Cost: 2.15     Valid Accuracy: 0.701
# Epoch: 89   - Cost: 2.13     Valid Accuracy: 0.701
# Epoch: 90   - Cost: 2.12     Valid Accuracy: 0.702
# Epoch: 91   - Cost: 2.11     Valid Accuracy: 0.704
# Epoch: 92   - Cost: 2.09     Valid Accuracy: 0.706
# Epoch: 93   - Cost: 2.08     Valid Accuracy: 0.708
# Epoch: 94   - Cost: 2.07     Valid Accuracy: 0.71
# Epoch: 95   - Cost: 2.05     Valid Accuracy: 0.712
# Epoch: 96   - Cost: 2.04     Valid Accuracy: 0.714
# Epoch: 97   - Cost: 2.03     Valid Accuracy: 0.715
# Epoch: 98   - Cost: 2.02     Valid Accuracy: 0.716
# Epoch: 99   - Cost: 2.0      Valid Accuracy: 0.719
# Epoch: 100  - Cost: 1.99     Valid Accuracy: 0.72
# Epoch: 101  - Cost: 1.98     Valid Accuracy: 0.722
# Epoch: 102  - Cost: 1.97     Valid Accuracy: 0.723
# Epoch: 103  - Cost: 1.96     Valid Accuracy: 0.724
# Epoch: 104  - Cost: 1.95     Valid Accuracy: 0.725
# Epoch: 105  - Cost: 1.93     Valid Accuracy: 0.726
# Epoch: 106  - Cost: 1.92     Valid Accuracy: 0.728
# Epoch: 107  - Cost: 1.91     Valid Accuracy: 0.729
# Epoch: 108  - Cost: 1.9      Valid Accuracy: 0.73
# Epoch: 109  - Cost: 1.89     Valid Accuracy: 0.731
# Epoch: 110  - Cost: 1.88     Valid Accuracy: 0.732
# Epoch: 111  - Cost: 1.87     Valid Accuracy: 0.733
# Epoch: 112  - Cost: 1.86     Valid Accuracy: 0.734
# Epoch: 113  - Cost: 1.85     Valid Accuracy: 0.735
# Epoch: 114  - Cost: 1.84     Valid Accuracy: 0.736
# Epoch: 115  - Cost: 1.83     Valid Accuracy: 0.737
# Epoch: 116  - Cost: 1.82     Valid Accuracy: 0.737
# Epoch: 117  - Cost: 1.81     Valid Accuracy: 0.738
# Epoch: 118  - Cost: 1.81     Valid Accuracy: 0.739
# Epoch: 119  - Cost: 1.8      Valid Accuracy: 0.74
# Epoch: 120  - Cost: 1.79     Valid Accuracy: 0.74
# Epoch: 121  - Cost: 1.78     Valid Accuracy: 0.742
# Epoch: 122  - Cost: 1.77     Valid Accuracy: 0.744
# Epoch: 123  - Cost: 1.76     Valid Accuracy: 0.745
# Epoch: 124  - Cost: 1.75     Valid Accuracy: 0.745
# Epoch: 125  - Cost: 1.74     Valid Accuracy: 0.745
# Epoch: 126  - Cost: 1.74     Valid Accuracy: 0.746
# Epoch: 127  - Cost: 1.73     Valid Accuracy: 0.747
# Epoch: 128  - Cost: 1.72     Valid Accuracy: 0.748
# Epoch: 129  - Cost: 1.71     Valid Accuracy: 0.749
# Epoch: 130  - Cost: 1.7      Valid Accuracy: 0.749
# Epoch: 131  - Cost: 1.7      Valid Accuracy: 0.75
# Epoch: 132  - Cost: 1.69     Valid Accuracy: 0.751
# Epoch: 133  - Cost: 1.68     Valid Accuracy: 0.752
# Epoch: 134  - Cost: 1.67     Valid Accuracy: 0.753
# Epoch: 135  - Cost: 1.67     Valid Accuracy: 0.754
# Epoch: 136  - Cost: 1.66     Valid Accuracy: 0.755
# Epoch: 137  - Cost: 1.65     Valid Accuracy: 0.755
# Epoch: 138  - Cost: 1.64     Valid Accuracy: 0.756
# Epoch: 139  - Cost: 1.64     Valid Accuracy: 0.757
# Epoch: 140  - Cost: 1.63     Valid Accuracy: 0.757
# Epoch: 141  - Cost: 1.62     Valid Accuracy: 0.758
# Epoch: 142  - Cost: 1.62     Valid Accuracy: 0.759
# Epoch: 143  - Cost: 1.61     Valid Accuracy: 0.759
# Epoch: 144  - Cost: 1.6      Valid Accuracy: 0.76
# Epoch: 145  - Cost: 1.6      Valid Accuracy: 0.761
# Epoch: 146  - Cost: 1.59     Valid Accuracy: 0.761
# Epoch: 147  - Cost: 1.58     Valid Accuracy: 0.762
# Epoch: 148  - Cost: 1.58     Valid Accuracy: 0.762
# Epoch: 149  - Cost: 1.57     Valid Accuracy: 0.763
# Epoch: 150  - Cost: 1.57     Valid Accuracy: 0.763
# Epoch: 151  - Cost: 1.56     Valid Accuracy: 0.764
# Epoch: 152  - Cost: 1.55     Valid Accuracy: 0.765
# Epoch: 153  - Cost: 1.55     Valid Accuracy: 0.765
# Epoch: 154  - Cost: 1.54     Valid Accuracy: 0.766
# Epoch: 155  - Cost: 1.54     Valid Accuracy: 0.767
# Epoch: 156  - Cost: 1.53     Valid Accuracy: 0.768
# Epoch: 157  - Cost: 1.52     Valid Accuracy: 0.768
# Epoch: 158  - Cost: 1.52     Valid Accuracy: 0.769
# Epoch: 159  - Cost: 1.51     Valid Accuracy: 0.769
# Epoch: 160  - Cost: 1.51     Valid Accuracy: 0.77
# Epoch: 161  - Cost: 1.5      Valid Accuracy: 0.77
# Epoch: 162  - Cost: 1.5      Valid Accuracy: 0.77
# Epoch: 163  - Cost: 1.49     Valid Accuracy: 0.771
# Epoch: 164  - Cost: 1.48     Valid Accuracy: 0.771
# Epoch: 165  - Cost: 1.48     Valid Accuracy: 0.771
# Epoch: 166  - Cost: 1.47     Valid Accuracy: 0.772
# Epoch: 167  - Cost: 1.47     Valid Accuracy: 0.772
# Epoch: 168  - Cost: 1.46     Valid Accuracy: 0.773
# Epoch: 169  - Cost: 1.46     Valid Accuracy: 0.773
# Epoch: 170  - Cost: 1.45     Valid Accuracy: 0.773
# Epoch: 171  - Cost: 1.45     Valid Accuracy: 0.774
# Epoch: 172  - Cost: 1.44     Valid Accuracy: 0.774
# Epoch: 173  - Cost: 1.44     Valid Accuracy: 0.774
# Epoch: 174  - Cost: 1.43     Valid Accuracy: 0.774
# Epoch: 175  - Cost: 1.43     Valid Accuracy: 0.775
# Epoch: 176  - Cost: 1.42     Valid Accuracy: 0.775
# Epoch: 177  - Cost: 1.42     Valid Accuracy: 0.776
# Epoch: 178  - Cost: 1.41     Valid Accuracy: 0.776
# Epoch: 179  - Cost: 1.41     Valid Accuracy: 0.776
# Epoch: 180  - Cost: 1.4      Valid Accuracy: 0.777
# Epoch: 181  - Cost: 1.4      Valid Accuracy: 0.777
# Epoch: 182  - Cost: 1.4      Valid Accuracy: 0.778
# Epoch: 183  - Cost: 1.39     Valid Accuracy: 0.778
# Epoch: 184  - Cost: 1.39     Valid Accuracy: 0.778
# Epoch: 185  - Cost: 1.38     Valid Accuracy: 0.779
# Epoch: 186  - Cost: 1.38     Valid Accuracy: 0.78
# Epoch: 187  - Cost: 1.37     Valid Accuracy: 0.781
# Epoch: 188  - Cost: 1.37     Valid Accuracy: 0.781
# Epoch: 189  - Cost: 1.37     Valid Accuracy: 0.782
# Epoch: 190  - Cost: 1.36     Valid Accuracy: 0.782
# Epoch: 191  - Cost: 1.36     Valid Accuracy: 0.782
# Epoch: 192  - Cost: 1.35     Valid Accuracy: 0.783
# Epoch: 193  - Cost: 1.35     Valid Accuracy: 0.784
# Epoch: 194  - Cost: 1.34     Valid Accuracy: 0.784
# Epoch: 195  - Cost: 1.34     Valid Accuracy: 0.785
# Epoch: 196  - Cost: 1.34     Valid Accuracy: 0.785
# Epoch: 197  - Cost: 1.33     Valid Accuracy: 0.786
# Epoch: 198  - Cost: 1.33     Valid Accuracy: 0.786
# Epoch: 199  - Cost: 1.32     Valid Accuracy: 0.787
# Test Accuracy: 0.794300019741
# CPU times: user 2min 27s, sys: 6.38 s, total: 2min 33s
# Wall time: 1min 24s
